# %%
import pandas as pd
import csv
df = pd.read_csv("C:\Users\ravindra.pratapsingh\python\practice\sales_data.csv")
print(df.head(1))
# Out:
#   Cell In[17], line 3
#     df = pd.read_csv("C:\Users\ravindra.pratapsingh\python\practice\sales_data.csv")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
goals = pd.Series(
    [12,8,7,5,6,9],
    index = ["Messi","Ronaldo","Ney","Mb","goat","test"])
print(goals)
# Out:
# Messi      12
# Ronaldo     8
# Ney         7
# Mb          5
# goat        6
# test        9
# dtype: int64
